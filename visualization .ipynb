# %%
import seaborn as sb
import matplotlib as plt
import numpy as np
import scipy as sc
from scipy import stats
import pandas as pd

# %%
df = pd.read_csv("C:/Users/harshit/Desktop/Covid_project/merged.csv")
df.shape
# Out:
# (770, 27)

# %%
df.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed', 'Sno_x', 'NumPrimaryHealthCenters_HMIS',
#        'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18', 'Sno_y', 'Population',
#        'Rural population', 'Urban population', 'Area', 'Density',
#        'Gender Ratio'],
#       dtype='object')

# %%
sb.relplot(x="Confirmed",y="State/UnionTerritory", hue="Deaths",data=df)

# %%
#del df['Time']
del df['Sno_x']
del df['Sno_y']

#df.drop(columns=['Sno'])

# %%
df1 = pd.read_csv("C:/Users/harshit/Desktop/Covid_project/AgeGroupDetails.csv")

# %%
import matplotlib.pyplot as plt
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = df1['AgeGroup']
sizes = df1['TotalCases']

fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.rcParams["figure.figsize"] = (12.4,4.8)
plt.show()

# %%
df.shape
# Out:
# (770, 25)

# %%
df.to_csv (r"C:/Users/harshit/Desktop/Covid_project/merged1.csv", index = False, header=True)

# %%
df['Deaths'].describe()
# Out:
# count    770.000000
# mean       1.168831
# std        4.017849
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       64.000000
# Name: Deaths, dtype: float64

# %%
df.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed', 'NumPrimaryHealthCenters_HMIS',
#        'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18', 'Population',
#        'Rural population', 'Urban population', 'Area', 'Density',
#        'Gender Ratio'],
#       dtype='object')

# %%
columns_list=[ 'Cured', 'Deaths', 'Confirmed',
       'NumPrimaryHealthCenters_HMIS', 'NumCommunityHealthCenters_HMIS',
       'NumSubDistrictHospitals_HMIS', 'NumDistrictHospitals_HMIS',
       'TotalPublicHealthFacilities_HMIS', 'NumPublicBeds_HMIS',
       'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
       'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18', 'Population',
       'Rural population', 'Urban population', 'Area', 'Density',
       ]
#x=[]
#for i in columns:
print(df[columns_list].sum(axis=0))
# Out:
# Cured                               2.833000e+03
# Deaths                              9.000000e+02
# Confirmed                           3.713800e+04
# NumPrimaryHealthCenters_HMIS        8.144640e+05
# NumCommunityHealthCenters_HMIS      1.545750e+05
# NumSubDistrictHospitals_HMIS        3.768500e+04
# NumDistrictHospitals_HMIS           2.722400e+04
# TotalPublicHealthFacilities_HMIS    1.033948e+06
# NumPublicBeds_HMIS                  2.129252e+07
# NumRuralHospitals_NHP18             5.565080e+05
# NumRuralBeds_NHP18                  8.064419e+06
# NumUrbanHospitals_NHP18             1.130570e+05
# NumUrbanBeds_NHP18                  1.238412e+07
# Population                          3.267897e+10
# Rural population                    2.189259e+10
# Urban population                    1.078638e+10
# dtype: float64

# %%
plt.rcParams['figure.figsize']=[16,12]

for index, Deaths in enumerate(df.Sno):
    plt.subplot(3,3,index+1)
    plt.plot(df['State/UnionTerritory'])
    plt.plot(np.arange(0,10), np.zeros(10))#base line
    plt.title(df['State/UnionTerritory'][index])
    plt.ylim(ymin=-.2, ymax=.3)
    plt.show()
# Out:
# D:\anaconda\lib\site-packages\matplotlib\axes\_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# D:\anaconda\lib\site-packages\matplotlib\axes\_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# D:\anaconda\lib\site-packages\matplotlib\axes\_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# D:\anaconda\lib\site-packages\matplotlib\axes\_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# ...
